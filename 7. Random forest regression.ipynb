# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor

# %matplotlib inline

# %%
loc = "data/Part 2 - Regression/Section 9 - Random Forest Regression/Python/"

dataset = pd.read_csv(loc + 'Position_Salaries.csv')
dataset.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
X = dataset.iloc[:, 1:2].values

# %%
y = dataset.iloc[:, 2].values

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=0)

# %%
# Feature scaling
# sc_X = StandardScaler()
# X_train = sc_X.fit_transform(X_train)
# X_test = sc_X.transform(X_test)

# %%
# Fitting the Regression Model to the 
regressor = RandomForestRegressor(n_estimators=300, random_state=0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=0)

# %%
# Predicting a new result
y_pred = regressor.predict(np.array(6.5).reshape(-1, 1))
y_pred
# Out:
# array([160333.33333333])

# %%
# Visualising the Regression results
plt.scatter(X, y, color='red')
plt.plot(X, regressor.predict(X), color='blue')
plt.title('Truth of Bluff (Random forest)')
plt.xlabel('Position level')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
# Visualising the Regression results (for higher resolution and smoother curve)
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color='red')
plt.plot(X_grid, regressor.predict(X_grid), color='blue')
plt.title('Truth of Bluff (Random forest)')
plt.xlabel('Position level')
plt.ylabel('Salary')
# Out:
# /var/folders/wt/fs62y8p10lxgyr__1q15y4_m0000gn/T/ipykernel_4078/2813910250.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.01)
# Text(0, 0.5, 'Salary')
